# %% [markdown]
# # Dungeon Adventure Game - Instructions
#
# In this exercise, you will build a text-based dungeon adventure game in Python.
#
# You will apply everything you've learned so far, including:
# - Variables
# - Operators
# - Lists
# - Dictionaries
# - Loops
# - Conditionals
# - The `random` module
#
# Follow the prompts in each section to build your game step by step. By the end, you will have a fully functioning game where the player can explore rooms, search for treasure, avoid traps, and see their final score based on the treasures collected.
#
# Complete each section before moving on to the next.

# %%
import random
# Step 1: Player Setup
# Prompt the player for their name.
# Set health to 10.
# Create an empty list to store their inventory.
player_name = input("Enter your name: ")
player_health = 300  # You can change this to 10 if you want a harder game
inventory = []

# %%
# Step 2: Treasure Dictionary
# Create a dictionary of treasures where the keys are treasure names
# and the values are the gold value of each treasure.
treasures = {
    "gold coin": 10,
     "silver coin": 5,
     "silver sword": 50,
     "golden crown": 100,
     "ancient scroll": 40,
     "diamond": 150,
     "emerald": 70,
     "ruby": 80,
}

print(f"\nWelcome to the Dungeon Adventure, {player_name}! Your journey begins now.")
print(f"You have {player_health} health points and an empty inventory.")
# Out:
# Welcome to the Dungeon Adventure, ! Your journey begins now.
# You have 100 health points and an empty inventory.

# %%
# Step 3: Game Loop - Moving through 5 rooms
# Use a for loop to represent rooms 1 to 5.
# In each room, display the current room number and the options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
# Make sure to handle each option appropriately.
for room_number in range(1, 6):
    if player_health <= 0:
        print("Game Over! You have no health left.")
        break

    print(f"\n--- Room {room_number} ---")

    while True:
        print("Options:")
        print("1. Search for treasure")
        print("2. Move to next room")
        print("3. Check health and inventory")
        print("4. Quit the game")

        choice = input("Choose an option (1-4): ").strip()

# Step 4: Implement treasure search
# If the player chooses to search, randomly decide if they find treasure or a trap.
# If treasure, randomly pick from the treasure dictionary and add to inventory.
# If trap, deduct 2 health points and print a message.
if choice == '1':
            chance = random.randint(1, 10)
            if chance <= 7:
                found = random.choice(list(treasures.keys()))
                inventory.append(found)
                print(f"You found a {found}! It is worth {treasures[found]} gold.")
            else:
                player_health -= 2
                print("You triggered a trap! You lost 2 health points.")

# Step 5: Check health
# If health drops to 0 or below, print a Game Over message and break the loop
 # Step 5: Check health
if player_health <= 0:
    print("Game Over! You have no health left.")
    break

elif choice == '2':
        print(f"Moving to Room {room_number + 1}...")
        break  # Proceed to next room

    elif choice == '3':
        print(f"\nHealth: {player_health}")
        print("Inventory:", inventory if inventory else "Empty")

    elif choice == '4':
        print("Thanks for playing! Goodbye!")
        break

        else:
            print("Invalid choice. Please choose a valid option (1-4).")
# Out:
# --- Room 1 ---
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game
#
# Health: 100
# Inventory: Empty
# Options:
# 1. Search for treasure
# 2. Move to next room
# 3. Check health and inventory
# 4. Quit the game

# %%
# Step 6: End of Game Summary
# If the player quits or finishes all rooms, calculate the total value of the collected treasures.
# Loop through the inventory and sum the gold value using the treasure dictionary.
# Print the final health, inventory, and total treasure value.
print("\n--- Game Summary ---")
print(f"Adventurer: {player_name}")
print(f"Final Health: {player_health}")
print("Inventory:", inventory if inventory else "Empty")
total_gold = sum(treasures[item] for item in inventory)
print(f"Total Treasure Value: {total_gold} gold")
print("Thank you for playing Dungeon Adventure!")
# Out:
# --- Game Summary ---
# Adventurer:
# Final Health: 100
# Inventory: Empty
# Total Treasure Value: 0 gold
# Thank you for playing Dungeon Adventure!
